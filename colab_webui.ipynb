# %% [markdown]
# <a href="https://colab.research.google.com/github/abeliu1029/Cpp_Primer_Practice/blob/master/colab_webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 环境配置 environment

# %%
# !pip install -q condacolab
# Setting up condacolab and installing packages
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")

# %cd -q /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd -q GPT-SoVITS
# !bash install.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:52
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 4997, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 4997 (delta 73), reused 34 (delta 34), pack-reused 4826 (from 2)
# Receiving objects: 100% (4997/4997), 13.14 MiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (2865/2865), done.
# Installing GCC...
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# / Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='repo.anaconda.com', port=443): Read timed out. (read timeout=9.15)")': /pkgs/r/noarch/repodata.json.zst
#
# done
# done
#
# ## Package Plan ##
#
# ...

# %%
# @title UVR5 Pretrained Models
# !wget https://www.modelscope.cn/models/XXXXRT/UVR5Weights4GSV/resolve/master/uvr5_weights.zip
# !unzip uvr5_weights.zip
# !rm -rf uvr5_weights.zip
# !mv uvr5_weights/* tools/uvr5/uvr5_weights
# !rm -rf uvr5_weights
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2025-04-19 08:15:40--  https://www.modelscope.cn/models/XXXXRT/UVR5Weights4GSV/resolve/master/uvr5_weights.zip
# Resolving www.modelscope.cn (www.modelscope.cn)... 47.251.62.57
# Connecting to www.modelscope.cn (www.modelscope.cn)|47.251.62.57|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-04-19 08:15:41 ERROR 404: Not Found.
#
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# unzip:  cannot find or open uvr5_weights.zip, uvr5_weights.zip.zip or uvr5_weights.zip.ZIP.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# mv: cannot stat 'uvr5_weights/*': No such file or directory
# ...

# %%
# !sed -i '10s/False/True/' /content/GPT-SoVITS/config.py
# %cd /content/GPT-SoVITS/
# !/usr/local/bin/python  webui.py
# Out:
# sed: can't read /content/GPT-SoVITS/config.py: No such file or directory
# [Errno 2] No such file or directory: '/content/GPT-SoVITS/'
# /content
# python3: can't open file '/content/webui.py': [Errno 2] No such file or directory

# %%
# !/usr/local/bin/pip install ipykernel
# !sed -i '10s/False/True/' /content/GPT-SoVITS/config.py
# %cd /content/GPT-SoVITS/
# !/usr/local/bin/python  webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /content/GPT-SoVITS
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /content/GPT-SoVITS/webui.py:297: SyntaxWarning: invalid escape sequence '\d'
#   parts = re.split("(\d+)", s)

# %%
from google.colab import drive
drive.mount('/content/drive')
